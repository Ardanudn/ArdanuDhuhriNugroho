# %% [markdown]
# <a href="https://colab.research.google.com/github/Ardanudn/ArdanuDhuhriNugroho/blob/master/Praktikum01/Praktikum01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Fri Sep 30 11:32:06 2022

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Fri Sep 30 11:32:54 2022

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
#  amikom.jpg					       'PROJECT PM.ipynb'
#  CardioKelompokFull.ipynb			        testmodel.ipynb
# 'CNN CIFAR-10.ipynb'				       'Test project2.ipynb'
#  heart-disease-classifications-machine-learning.ipynb   UAS.ipynb
#  Hello.py					        Untitled
# 'Latihan Iris Dataset.ipynb'			        Untitled0.ipynb
# 'Praktikum1 (1).ipynb'				       'Untitled (1)'
#  Praktikum1.ipynb				        Untitled1.ipynb
# 'Praktikum 3.ipynb'				       'Visualisasi data.ipynb'
#  PraktikumBPP.ipynb

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/Hello.py"
# Out:
# Hello World

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab.patches import cv2_imshow  
img = cv2.imread('/content/drive/MyDrive/Visi Komputer/Praktikum01/amikom.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
grayImg = cv2.cvtColor(np.array(img),cv2.COLOR_BGR2GRAY)
cv2_imshow(grayImg)
# Out:
# <PIL.Image.Image image mode=RGB size=2560x2048 at 0x7F1E2C5CB910>
# <PIL.Image.Image image mode=L size=2560x2048 at 0x7F1E2C5CBFD0>

# %% [markdown]
# PRE TEST
# POST TEST
#
#
# Tugas
# 1.Jelaskan Perbedaan PCD dengan Computer Vision
# 2.Sebutkan beberapa library yang berkaitan dengan CV
# 3.Jelaskan konsep konversi RGB to GRAY beserta rumusnya
